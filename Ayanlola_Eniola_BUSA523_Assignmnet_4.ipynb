# %% [markdown]
# # Assigment 4

# %% [markdown]
# ### Importing data

# %%
#Import the dataset:

import pandas as pd

data = pd.read_csv("Data.csv", header = 0, index_col = 0)


data
# Out:
#             Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# Date
# 5/2/2010          42.31       2.572        NaN        NaN        NaN
# 12/2/2010         38.51       2.548        NaN        NaN        NaN
# 19/02/2010        39.93       2.514        NaN        NaN        NaN
# 26/02/2010        46.63       2.561        NaN        NaN        NaN
# 5/3/2010          46.50       2.625        NaN        NaN        NaN
# ...                 ...         ...        ...        ...        ...
# 28/09/2012        76.08       3.666    3666.27       7.64       1.65
# 5/10/2012         68.55       3.617    8077.89        NaN      18.22
# 12/10/2012        62.99       3.601    2086.18        NaN       8.11
# 19/10/2012        67.97       3.594     950.33        NaN       4.93
# 26/10/2012        69.16       3.506    2585.85      31.75       6.00
#
#             MarkDown4  MarkDown5         CPI  Unemployment     Day type  \
# Date
# ...

# %%
# Fill in missing data - using "bfill"

import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("data.csv", header = 0, index_col = 0)

data

data.fillna(method = "bfill")  #backwards fill
# Out:
#             Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# Date
# 5/2/2010          42.31       2.572   10382.90    6115.67     215.07
# 12/2/2010         38.51       2.548   10382.90    6115.67     215.07
# 19/02/2010        39.93       2.514   10382.90    6115.67     215.07
# 26/02/2010        46.63       2.561   10382.90    6115.67     215.07
# 5/3/2010          46.50       2.625   10382.90    6115.67     215.07
# ...                 ...         ...        ...        ...        ...
# 28/09/2012        76.08       3.666    3666.27       7.64       1.65
# 5/10/2012         68.55       3.617    8077.89      31.75      18.22
# 12/10/2012        62.99       3.601    2086.18      31.75       8.11
# 19/10/2012        67.97       3.594     950.33      31.75       4.93
# 26/10/2012        69.16       3.506    2585.85      31.75       6.00
#
#             MarkDown4  MarkDown5         CPI  Unemployment     Day type  \
# Date
# ...

# %% [markdown]
# ### Histogram

# %%
#A. Histogram

#Histograms visualize quantitative data or numerical data, whereas bar charts display categorical variables.

# importing libraries

import matplotlib.pyplot as plt

import seaborn as sns

import pandas as pd

# load the Data.csv dataset

data = pd.read_csv("data.csv")


# view the dataset

#print(data.head(14))
 


plt.hist(data['dept_1 sales'],

         alpha=0.5,

         label='Dept1 Sales',

         color='red') # customized color parameter


plt.title("Dept 1 Sales by Day Type")

plt.show()

# %%
#Histogram - plotting overlapping histograms for 3 department sales


import matplotlib.pyplot as plt

import seaborn as sns

import pandas as pd

# load the Data.csv dataset

data = pd.read_csv("data.csv")


# view the dataset

#print(data.head(14))
 


plt.hist(data['dept_1 sales'],

         alpha=0.5,

         label='Dept1 Sales',

         color='red') # customized color parameter

plt.hist(data['dept_2 sales'],

         alpha=0.5,

         label='Dept2 Sales',

         color='green')

 

plt.hist(data['dept_3 sales'],

         alpha=0.5,

         label='Dept3 Sales',

         color='yellow')

plt.legend(loc='upper right')

plt.title("Dept 1, 2 & 3 Sales Histogram")

plt.show()

# %% [markdown]
# ### Bar Chart

# %%
#B. Bar chart  

#bar charts display categorical variables

#Unlike histograms, bar charts have a finite set of categories

#Bar Chart on the effect of 'Day Type' on Department 1 Sales.

import matplotlib.pyplot as plt

import pandas as pd

import matplotlib as mlp

df = pd.read_csv('data.csv', index_col = 9)

#df -DataFrame

df1 = df.sort_values('Day type', ascending=False)


X = list(df1.iloc[:, 9])    #List of Day Type

Y = list(df1.iloc[:, 10])   #List of Dept 1 Sales

 

# Plot the data using bar() method

plt.bar(X, Y, color='g')

plt.title("Dept 1 Sales by Day Type")

plt.xlabel("Day Type")

plt.ylabel("Dept Sales")

plt.show()

# %%
#Bar Chart on the Department 1 Sales by year.

import matplotlib.pyplot as plt

import pandas as pd

df = pd.read_csv('data.csv')

#Create and Add another column that extracts the year from Date Column

df['Year'] = df['Date'].str[-4:]

#Replaceing spaces in column names with _

df.columns = [c.replace(' ', '_') for c in df.columns]

#Sort the Year column in ascending order

df1 = df.sort_values('Year', ascending=True)

#Plot the data using bar() for the Bar Chart - X = Year and Y = Sales 1 Dept Data.

plt.bar(df1.Year, df1.dept_1_sales, color='y')

plt.title("Dept Sales by Year")

plt.xlabel("Years")

plt.ylabel("Dept Sales")
# Out:
# Text(0, 0.5, 'Dept Sales')

# %%
#Bar Chart on the 'Department 1, 2, 3 Sales by year.

import matplotlib.pyplot as plt

import pandas as pd

df = pd.read_csv('data.csv')

#Create and Add another column that extracts the year from Date Column

df['Year'] = df['Date'].str[-4:]

df.columns = [c.replace(' ', '_') for c in df.columns]

#Sort the Year column in ascending order

df1 = df.sort_values('Year', ascending=True)

#Plot the data using bar() for the Bar Chart - X = Year and Y = Sales (1/2/3) Dept Data.

plt.bar(df1.Year, df1.dept_1_sales, color='g')

plt.bar(df1.Year, df1.dept_2_sales, color='r')

plt.bar(df1.Year, df1.dept_3_sales, color='b')

plt.title("Dept 1,2 3 Sales by Year")

plt.xlabel("Years")

plt.ylabel("Dept Sales")
# Out:
# Text(0, 0.5, 'Dept Sales')

# %% [markdown]
# ### Line Chart

# %%
#C. Line chart 

#Line Chart on the 3 Departmental Sales by Date.

#Column Names used for the DataSet: Date, dept_1 sales, dept_2 sales, dept_3 sales

import matplotlib.pyplot as plt

#Making it interactive

# %matplotlib notebook

import pandas as pd

import matplotlib as mlp

from matplotlib.pyplot import figure

df = pd.read_csv('data.csv')

#What are the columns in this dataframe:

#df.columns

#Removing spaces in column name with _:

df.columns = [c.replace(' ', '_') for c in df.columns]

df.columns

#Figure Size

figure(figsize=(13, 10), dpi=80)

#Ploting - remove # to see the other 2 departments

plt.plot(df.Date, df.dept_1_sales)

#plt.plot(df.Date, df.dept_2_sales)

#plt.plot(df.Date, df.dept_3_sales)

plt.title("Departmental Sales by Date")

plt.xlabel("Dates")

plt.ylabel("Dept 1, 2, 3 Sales")

plt.legend(["Dept 1 Sales", "Dept 2 Sales", "Dept 3 Sales"])

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1040">

# %%
#Viewing all 3 departmnets

import matplotlib.pyplot as plt

#Making it interactive

# %matplotlib notebook

import pandas as pd

import matplotlib as mlp

from matplotlib.pyplot import figure

df = pd.read_csv('data.csv')

#What are the columns in this dataframe:

#df.columns

#Removing spaces in column name with _:

df.columns = [c.replace(' ', '_') for c in df.columns]

df.columns

#Figure Size

figure(figsize=(13, 10), dpi=80)

#Ploting - remove # to see the other 2 departments

plt.plot(df.Date, df.dept_1_sales)

plt.plot(df.Date, df.dept_2_sales)

plt.plot(df.Date, df.dept_3_sales)

plt.title("Departmental Sales by Date")

plt.xlabel("Dates")

plt.ylabel("Dept 1, 2, 3 Sales")

plt.legend(["Dept 1 Sales", "Dept 2 Sales", "Dept 3 Sales"])

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1169.7777777777778">

# %%
#Line Chart on the effect of 'Temperature' on three Department Sales.

#Names of Columns used for the DataSet: Temperature, dept_1 sales, dept_2 sales, dept_3 sales

import matplotlib.pyplot as plt

import pandas as pd

import matplotlib as mlp

from matplotlib.pyplot import figure

df = pd.read_csv('data.csv')

#What are the columns in this dataframe:

#df.columns

#Removing spaces in column name with _:

df.columns = [c.replace(' ', '_') for c in df.columns]

df1 = df.sort_values('Temperature', ascending=True)

#Figure Size

figure(figsize=(10, 8), dpi=80)

#Ploting

plt.plot(df1.Temperature, df1.dept_1_sales)

plt.plot(df1.Temperature, df1.dept_2_sales)

plt.plot(df1.Temperature, df1.dept_3_sales)

plt.title("Three Departmental Sales on Temperature")

plt.xlabel("Temperature")

plt.ylabel("Dept 1, 2, 3 Sales")

plt.legend(["Dept 1 Sales", "Dept 2 Sales", "Dept 3 Sales"])

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# # Area plot

# %%
#D. Area chart

# Using CPI for y-axis

# What is the impact on the bottom-line (Sales) for 3 depts?

#Import the Libraries

import matplotlib.pyplot as plt

# %matplotlib inline

from matplotlib.pyplot import figure

df = pd.read_csv('data.csv')

#Remove spaces in column name with _:

df.columns = [c.replace(' ', '_') for c in df.columns]

#Plotting begins

#Figure Size

figure(figsize=(12, 10), dpi=80)

plt.title("Three Departmental Sales on Consumer Price Index (CPI)")

plt.xlabel("Consumer Price Index (CPI)")

plt.ylabel("Dept 1, 2, 3 Sales")

plt.legend(["Dept 1 Sales", "Dept 2 Sales", "Dept 3 Sales"])

plt.stackplot(df.CPI,df.dept_1_sales, df.dept_2_sales, df.dept_3_sales)

plt.show()

# %% [markdown]
# # Scatter plot

# %%
#E. Scatter plot- Used to find the correlation between at least 2 variabes

import matplotlib.pyplot as plt

import pandas as pd

df = pd.read_csv('data.csv', index_col = 0)

df.head()

 

df.plot.scatter(x='Fuel_Price', y='dept_1 sales')

# df.plot.scatter(x='Fuel_Price', y='dept_2 sales')

# df.plot.scatter(x='Fuel_Price', y='dept_3 sales')

 

#Let's add a regression line:

import seaborn as sns

sns.set_style('white')

sns.set_style('ticks')

sns.regplot(x='Fuel_Price', y='dept_3 sales', color='g', data=df)
# Out:
# <AxesSubplot:xlabel='Fuel_Price', ylabel='dept_3 sales'>
